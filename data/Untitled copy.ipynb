# %%
7 * 3
2 + 1
# Out:
# 3

# %%
print(7 * 3)
print(2 + 1)
# Out:
# 21
# 3

# %% [markdown]
# x = 6 * 7 + 12
# print(x)

# %% [markdown]
# $\sum_{i=1}^{N} 2^{-i} \approx 1$

# %% [markdown]
# 2 ^ 4

# %% [markdown]
# 2^4

# %%
2 ^ 4
# Out:
# 6
