# %%
grades = {'Juan': {'Maths': 2},
          'John': {'History': 1, 'Biology': 3},
          'Gianni': {'Biology': 1}}

# %%
grades['Juan']['History'] = 2
grades['Juan']['Biology'] = 1

grades['John']['Maths'] = 1

grades['Gianni']['History'] = 4
grades['Gianni']['Maths'] = 3
print(grades)
# Out:
# {'Juan': {'Maths': 2, 'History': 2, 'Biology': 1}, 'John': {'History': 1, 'Biology': 3, 'Maths': 1}, 'Gianni': {'Biology': 1, 'History': 4, 'Maths': 3}}

# %%
for numbers in [ 0,1,1,2,3,5]:
   double = numbers * 2
   print(numbers, double)
# Out:
# 0 0
# 1 2
# 1 2
# 2 4
# 3 6
# 5 10

# %%
for numbers in [90,3,4]:
    print (numbers)
# Out:
# 90
# 3
# 4

# %%
primes = 2, 3, 5
for numbers in primes:
    squared= numbers*2
    cubed= numbers*3
    print (primes, squared, cubed)
# Out:
# (2, 3, 5) 4 6
# (2, 3, 5) 6 9
# (2, 3, 5) 10 15

# %%
for numbers in range(0, 3):
    print(numbers)
# Out:
# 0
# 1
# 2

# %%
for fruits in range ( 3, 8):
    print (fruits)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
for numbers in [3,4,5]:
    print (numbers)
# Out:
# 3
# 4
# 5

# %%
for numbers in range [3,4]:
    print (numbers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 for numbers in range [3,4]:
#       2     print (numbers)
#
# TypeError: type 'range' is not subscriptable

# %%
for numbers in range (3,4):
    print (numbers)
# Out:
# 3

# %%
primes = [2, 3, 5]
for numbers in (primes):
    sqared = numbers * 2
    cubed = numbers * 3
    print (numbers, squared, cubed)
# Out:
# 2 10 6
# 3 10 9
# 5 10 15
