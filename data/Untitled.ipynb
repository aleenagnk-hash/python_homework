# %%
s = "The quick blah blah blah"

# %%
s.split()
# Out:
# ['The', 'quick', 'blah', 'blah', 'blah']

# %%
shopping = ["bread", "potatos", "mango", "flour", "avocado"]

# %%
shopping
# Out:
# ['bread', 'potatos', 'mango', 'flour', 'avocado']

# %%
shopping.sort()

# %%
shopping
# Out:
# ['avocado', 'bread', 'flour', 'mango', 'potatos']

# %%
shopping.append(milk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 shopping.append(milk)
#
# NameError: name 'milk' is not defined

# %%
shopping.append("milk")

# %%
shopping
# Out:
# ['avocado', 'bread', 'flour', 'mango', 'potatos', 'milk']

# %%
# milk should go top of list
shopping.insert(0, "milk!")

# %%
shopping
# Out:
# ['milk!', 'avocado', 'bread', 'flour', 'mango', 'potatos', 'milk']

# %%
shopping.pop()
# Out:
# 'milk'

# %%
shopping
# Out:
# ['milk!', 'avocado', 'bread', 'flour', 'mango', 'potatos']

# %%
shopping.pop(2)
# Out:
# 'bread'

# %%
shopping
# Out:
# ['milk!', 'avocado', 'flour', 'mango', 'potatos']

# %%
words = s.split()

# %%
words
# Out:
# ['The', 'quick', 'blah', 'blah', 'blah']

# %%
words[2]
# Out:
# 'blah'

# %%
s[2]
# Out:
# 'e'

# %%
s[2]word[2]
# Out:
#   Cell In[23], line 1
#     s[2]word[2]
#         ^
# SyntaxError: invalid syntax

# %%
(s[2]) (word[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 (s[2]) (word[2])
#
# NameError: name 'word' is not defined

# %%
words[3][2]
# Out:
# 'a'

# %%
pressures = [0.273, 0.275, 0.277, 0.275, 0.276]

# %%
print('pressures:', pressures)
# Out:
# pressures: [0.273, 0.275, 0.277, 0.275, 0.276]

# %%
print(len(pressures)
# Out:
#   Cell In[29], line 1
#     print(len(pressures)
#                         ^
# _IncompleteInputError: incomplete input

# %%
print(len(pressures))
# Out:
# 5

# %%
print('zeroth item of pressures:', pressures[0])
# Out:
# zeroth item of pressures: 0.273

# %%
print('zeroth item of pressures:', pressure[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print('zeroth item of pressures:', pressure[3])
#
# NameError: name 'pressure' is not defined

# %%
print('zeroth item of pressures:', pressures[3])
# Out:
# zeroth item of pressures: 0.275

# %%
pressures[0] = 0.265

# %%
print('pressures is now:', pressures)
# Out:
# pressures is now: [0.265, 0.275, 0.277, 0.275, 0.276]

# %%
bp = [34, 54, 683, 98937, 456]

# %%
print('bp is marked as;'[2])

# %%
bp
# Out:
# [34, 54, 683, 98937, 456]

# %%
print('bp is marked as:', bp[2])
# Out:
# bp is marked as: 683

# %%
temperature = [ 12, 23, 9, 35, 0, 25]

# %%
print('temperature is ;' temperature[4])
# Out:
#   Cell In[41], line 1
#     print('temperature is ;' temperature[4])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('temperature is ;', temperature[4])
# Out:
# temperature is ; 0

# %%
Fibonacci Sequences = [0, 1, 1, 2, 3, 5, 8, 13, 21]
# Out:
#   Cell In[43], line 1
#     Fibonacci Sequences = [0, 1, 1, 2, 3, 5, 8, 13, 21]
#               ^
# SyntaxError: invalid syntax

# %%
Fibonacci Sequences = (0, 1, 1, 2, 3, 5, 8, 13, 21)
# Out:
#   Cell In[44], line 1
#     Fibonacci Sequences = (0, 1, 1, 2, 3, 5, 8, 13, 21)
#               ^
# SyntaxError: invalid syntax

# %%
fibonacci_sequences = [0, 1, 1, 2, 3, 5, 8, 13, 21]

# %%
print('Fibonacci Sequences are;', fibonacci_sequences)
# Out:
# Fibonacci Sequences are; [0, 1, 1, 2, 3, 5, 8, 13, 21]

# %%
fibonacci_sequences(append[8])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 fibonacci_sequences(append[8])
#
# NameError: name 'append' is not defined

# %%
fibonacci_sequences.append[8]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 fibonacci_sequences.append[8]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
fibonacci_sequences.append(8)

# %%
fibonacci_sequences
# Out:
# [0, 1, 1, 2, 3, 5, 8, 13, 21, 8, 8]

# %%
fibonacci_sequences.append(8)

# %%
print('new apended sequence is;', fibonacci_sequences)
# Out:
# new apended sequence is; [0, 1, 1, 2, 3, 5, 8, 13, 21, 8, 8, 8]

# %%
primes = [2, 3, 5]

# %%
print('primes is initially:', primes)
# Out:
# primes is initially: [2, 3, 5]

# %%
primes.append(7)

# %%
print('primes is now:', primes)
# Out:
# primes is now: [2, 3, 5, 7, 7]

# %%
primes.append(7)
print('primes is now:', primes)
# Out:
# primes is now: [2, 3, 5, 7, 7]

# %%
primes = [2, 3, 5, 7, 9]

# %%
print('primes before removing last item:', primes)
# Out:
# primes before removing last item: [2, 3, 5, 7, 9]

# %%
del primes[4]

# %%
print('primes after removing last item:', primes)
# Out:
# primes after removing last item: [2, 3, 5, 7]

# %%
element = 'carbon'

# %%
print (element [4])
# Out:
# o

# %%
'-'.join(['x', 'y', 'z'])
# Out:
# 'x-y-z'

# %%
element = 'helium'
print(element[-1])
# Out:
# m

# %%
element = 'fluorine'

# %%
print(element[::2])
# Out:
# furn

# %%
element = 'lithium'

# %%
print(element[0:20])
# Out:
# lithium

# %%
print(element[-1:3])
